# %%
# Libraries
import requests
import json
import pandas as pd

# %%
url_base = 'https://earthquake.usgs.gov/fdsnws/event/1/count?format=geojson'
contri = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2020-01-01&endtime=2020-12-31&minmagnitude=5'

# %%
r = requests.get(contri)

# %%
r.status_code
# Out:
# 200

# %%
#r.json()

# %%
df = pd.DataFrame(r.json()['features'])
df.head()
# Out:
#       type                                         properties  \
# 0  Feature  {'mag': 5, 'place': '7 km NNW of Shingli Bala,...
# 1  Feature  {'mag': 5, 'place': '4 km ENE of Funaishikawa,...
# 2  Feature  {'mag': 5.7, 'place': 'central Mid-Atlantic Ri...
# 3  Feature  {'mag': 5.3, 'place': '24 km SW of Sarangani, ...
# 4  Feature  {'mag': 6.4, 'place': '2 km WSW of Petrinja, C...
#
#                                             geometry          id
# 0  {'type': 'Point', 'coordinates': [72.9466, 34....  us6000d49f
# 1  {'type': 'Point', 'coordinates': [140.6097, 36...  us6000d45q
# 2  {'type': 'Point', 'coordinates': [-21.1005, -0...  us6000d454
# 3  {'type': 'Point', 'coordinates': [125.2951, 5....  us6000d40v
# 4  {'type': 'Point', 'coordinates': [16.2573, 45....  us6000d3zh

# %%
df1 = pd.json_normalize(df['properties'])
df1.head()
# Out:
#    mag                               place           time        updated  tz  \
# 0  5.0  7 km NNW of Shingli Bala, Pakistan  1609306423546  1611737430115 NaN
# 1  5.0     4 km ENE of Funaishikawa, Japan  1609288527718  1614655202040 NaN
# 2  5.7          central Mid-Atlantic Ridge  1609284897647  1614655065196 NaN
# 3  5.3  24 km SW of Sarangani, Philippines  1609258908131  1614534556040 NaN
# 4  6.4       2 km WSW of Petrinja, Croatia  1609240794762  1615011579329 NaN
#
#                                                  url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail    felt  cdi    mmi  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...     2.0  3.8    NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...    26.0  5.0    NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...     NaN  NaN  0.000  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...     2.0  2.5    NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...  2544.0  9.1  8.623  ...
#
#                                   ids     sources  \
# 0                        ,us6000d49f,        ,us,
# 1                        ,us6000d45q,        ,us,
# 2  ,at00qm4k6a,pt20364002,us6000d454,  ,at,pt,us,
# 3                        ,us6000d40v,        ,us,
# 4  ,us6000d3zh,at00qm3m56,pt20364001,  ,us,at,pt,
#
#                                                types  nst   dmin   rms   gap  \
# 0                           ,dyfi,origin,phase-data,  NaN  1.119  1.18  42.0
# 1                           ,dyfi,origin,phase-data,  NaN  1.934  0.91  42.0
# 2  ,internal-origin,losspager,moment-tensor,origi...  NaN  9.629  0.72  46.0
# 3             ,dyfi,moment-tensor,origin,phase-data,  NaN  1.819  1.07  36.0
# 4  ,dyfi,general-text,ground-failure,impact-text,...  NaN  0.941  0.75  13.0
#
#   magType        type                                       title
# 0      mb  earthquake  M 5.0 - 7 km NNW of Shingli Bala, Pakistan
# 1     mww  earthquake     M 5.0 - 4 km ENE of Funaishikawa, Japan
# 2     mww  earthquake          M 5.7 - central Mid-Atlantic Ridge
# 3     mww  earthquake  M 5.3 - 24 km SW of Sarangani, Philippines
# 4     mww  earthquake       M 6.4 - 2 km WSW of Petrinja, Croatia
#
# [5 rows x 26 columns]

# %%
df2 = pd.json_normalize(df['geometry'])
df2.head()
# Out:
#     type                 coordinates
# 0  Point       [72.9466, 34.741, 10]
# 1  Point  [140.6097, 36.4858, 43.47]
# 2  Point     [-21.1005, -0.7603, 10]
# 3  Point      [125.2951, 5.2608, 35]
# 4  Point      [16.2573, 45.4244, 10]

# %%
# combinando dataframes de coordenadas y propiedades de los terremotos.
merge_df = pd.concat([df1, df2], axis=1)

# %%
merge_df.head()
# Out:
#    mag                               place           time        updated  tz  \
# 0  5.0  7 km NNW of Shingli Bala, Pakistan  1609306423546  1611737430115 NaN
# 1  5.0     4 km ENE of Funaishikawa, Japan  1609288527718  1614655202040 NaN
# 2  5.7          central Mid-Atlantic Ridge  1609284897647  1614655065196 NaN
# 3  5.3  24 km SW of Sarangani, Philippines  1609258908131  1614534556040 NaN
# 4  6.4       2 km WSW of Petrinja, Croatia  1609240794762  1615011579329 NaN
#
#                                                  url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail    felt  cdi    mmi  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...     2.0  3.8    NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...    26.0  5.0    NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...     NaN  NaN  0.000  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...     2.0  2.5    NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...  2544.0  9.1  8.623  ...
#
#                                                types nst   dmin   rms   gap  \
# 0                           ,dyfi,origin,phase-data, NaN  1.119  1.18  42.0
# 1                           ,dyfi,origin,phase-data, NaN  1.934  0.91  42.0
# 2  ,internal-origin,losspager,moment-tensor,origi... NaN  9.629  0.72  46.0
# 3             ,dyfi,moment-tensor,origin,phase-data, NaN  1.819  1.07  36.0
# 4  ,dyfi,general-text,ground-failure,impact-text,... NaN  0.941  0.75  13.0
#
#   magType        type                                       title   type  \
# 0      mb  earthquake  M 5.0 - 7 km NNW of Shingli Bala, Pakistan  Point
# 1     mww  earthquake     M 5.0 - 4 km ENE of Funaishikawa, Japan  Point
# 2     mww  earthquake          M 5.7 - central Mid-Atlantic Ridge  Point
# 3     mww  earthquake  M 5.3 - 24 km SW of Sarangani, Philippines  Point
# 4     mww  earthquake       M 6.4 - 2 km WSW of Petrinja, Croatia  Point
#
#                   coordinates
# 0       [72.9466, 34.741, 10]
# 1  [140.6097, 36.4858, 43.47]
# 2     [-21.1005, -0.7603, 10]
# 3      [125.2951, 5.2608, 35]
# 4      [16.2573, 45.4244, 10]
#
# [5 rows x 28 columns]

# %%
tabla_salida = merge_df[['mag','place','time','updated','tz','alert','status','tsunami','rms','magType','type','coordinates']]

# %%
tabla_salida.head()
# Out:
#    mag                               place           time        updated  tz  \
# 0  5.0  7 km NNW of Shingli Bala, Pakistan  1609306423546  1611737430115 NaN
# 1  5.0     4 km ENE of Funaishikawa, Japan  1609288527718  1614655202040 NaN
# 2  5.7          central Mid-Atlantic Ridge  1609284897647  1614655065196 NaN
# 3  5.3  24 km SW of Sarangani, Philippines  1609258908131  1614534556040 NaN
# 4  6.4       2 km WSW of Petrinja, Croatia  1609240794762  1615011579329 NaN
#
#     alert    status  tsunami   rms magType        type   type  \
# 0    None  reviewed        0  1.18      mb  earthquake  Point
# 1    None  reviewed        0  0.91     mww  earthquake  Point
# 2   green  reviewed        0  0.72     mww  earthquake  Point
# 3    None  reviewed        0  1.07     mww  earthquake  Point
# 4  orange  reviewed        0  0.75     mww  earthquake  Point
#
#                   coordinates
# 0       [72.9466, 34.741, 10]
# 1  [140.6097, 36.4858, 43.47]
# 2     [-21.1005, -0.7603, 10]
# 3      [125.2951, 5.2608, 35]
# 4      [16.2573, 45.4244, 10]

# %%
tabla_salida.columns = ['mag','place','time','updated','tz','alert','status','flag_tsunami','rms','magType','earthquake_type','coordinate_type','coordinates']

# %%
tabla_salida.head()
# Out:
#    mag                               place           time        updated  tz  \
# 0  5.0  7 km NNW of Shingli Bala, Pakistan  1609306423546  1611737430115 NaN
# 1  5.0     4 km ENE of Funaishikawa, Japan  1609288527718  1614655202040 NaN
# 2  5.7          central Mid-Atlantic Ridge  1609284897647  1614655065196 NaN
# 3  5.3  24 km SW of Sarangani, Philippines  1609258908131  1614534556040 NaN
# 4  6.4       2 km WSW of Petrinja, Croatia  1609240794762  1615011579329 NaN
#
#     alert    status  flag_tsunami   rms magType earthquake_type  \
# 0    None  reviewed             0  1.18      mb      earthquake
# 1    None  reviewed             0  0.91     mww      earthquake
# 2   green  reviewed             0  0.72     mww      earthquake
# 3    None  reviewed             0  1.07     mww      earthquake
# 4  orange  reviewed             0  0.75     mww      earthquake
#
#   coordinate_type                 coordinates
# 0           Point       [72.9466, 34.741, 10]
# 1           Point  [140.6097, 36.4858, 43.47]
# 2           Point     [-21.1005, -0.7603, 10]
# 3           Point      [125.2951, 5.2608, 35]
# 4           Point      [16.2573, 45.4244, 10]
